# %% [markdown]
# # SEO Crawl Dataset :weclouddata

# %%
#!pip install advertools

# %%
import pandas as pd
from advertools import crawl

# %%
#Another version 
#import pandas as pd
#import advertools as adv

#adv.crawl('https://weclouddata.com',  
           output_file='weclouddata2.jl',     
           follow_links=True,  
           allowed_domains=[ 'www.weclouddata.com'],  
           custom_settings={'LOG_FILE': 'weclouddata.log' })

# %%
#craw competitor lighthouselabs website
crawl('http://lighthouselabs.ca','lighthouselabs.jl',follow_links=True,custom_settings={'LOG_FILE': 'lighthouselabs.log'})

#lighthouselabs.jl size: 43.2 MB (45,322,014 bytes)

# %%
#compare jl size
#lighthouselabs.jl size: 43.2 MB (45,322,014 bytes), log size:0.98 MB (1,030,553 bytes)
#weclouddata.jl: 27.6 MB (28,992,698 bytes), log size:309 KB (317,218 bytes)

# %%
pd.set_option('display.max_columns',90)

# %%
#make the column width show all text
pd.set_option("display.max_colwidth",None)

# %%
df_labs=pd.read_json('lighthouselabs.jl',lines=True)

# %%
df_labs.head()
# Out:
#                                                                                                     url  \
# 0                                                                        https://www.lighthouselabs.ca/
# 1                                                         https://www.lighthouselabs.ca/en/all-programs
# 2   https://enterprise.lighthouselabs.ca/?utm_source=lhlwebsite&utm_medium=menu&utm_campaign=enterprise
# 3  https://enterprise.lighthouselabs.ca/?utm_source=lhlwebsite&utm_medium=menu&utm_campaign=programstab
# 4                                                                  https://www.lighthouselabs.ca/en/faq
#
#                                                  title  \
# 0  Canada's Leading Coding Bootcamp - Lighthouse Labs
# 1                      All Programs - Lighthouse Labs
# 2                                      Lighthouse Labs
# 3                                      Lighthouse Labs
# 4        Frequently Asked Questions - Lighthouse Labs
#
# ...

# %%
df_labs.shape
# Out:
# (2088, 113)

# %%
df_labs['h1']
# Out:
# 0                 Education done differently.
# 1                                         NaN
# 2          TECHNOLOGY TRAINING \nFOR TOMORROW
# 3          TECHNOLOGY TRAINING \nFOR TOMORROW
# 4                                        FAQ.
#                         ...
# 2083    \n      Challenge 19 Megathread\n
# 2084    \n      Challenge 20 Megathread\n
# 2085     \n      Challenge 1 Megathread\n
# 2086                                      NaN
# 2087                                      NaN
# Name: h1, Length: 2088, dtype: object

# %%
df_labs['h2']
# Out:
# 0       Our courses@@Mentored, Hands-On, Accelerated L...
# 1                                                     NaN
# 2       \n\t\t\t\t\tWORK WITH LIGHTHOUSE LABS TO UNLOC...
# 3       \n\t\t\t\t\tWORK WITH LIGHTHOUSE LABS TO UNLOC...
# 4                   Submit an Application@@Our  Ramblings
#                               ...
# 2083                                                  NaN
# 2084                                                  NaN
# 2085                                                  NaN
# 2086                                                  NaN
# 2087                                                  NaN
# Name: h2, Length: 2088, dtype: object

# %%
df_labs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2088 entries, 0 to 2087
# Columns: 113 entries, url to resp_headers_discourse-rate-limit-error-code
# dtypes: datetime64[ns](1), float64(8), int64(4), object(100)
# memory usage: 1.8+ MB

# %%
df_labs.columns
# Out:
# Index(['url', 'title', 'meta_desc', 'viewport', 'charset', 'h1', 'h2', 'h3',
#        'h4', 'canonical',
#        ...
#        'resp_headers_discourse-readonly', 'resp_headers_x-discourse-cached',
#        'resp_headers_x-discourse-trackview', 'og:ignore_canonical',
#        'resp_headers_last-modified', 'resp_headers_content-length',
#        'resp_headers_via', 'retry_times', 'resp_headers_retry-after',
#        'resp_headers_discourse-rate-limit-error-code'],
#       dtype='object', length=113)

# %% [markdown]
# ### Google 收录网站情况： site

# %% [markdown]
# 1.首先在做谷歌网站排名优化之前，先来看看自己网站在谷歌是否有排名，使用site:www.abc.com命令，看看自己网站在谷歌的收录和排名情况:
# save to excel

# %% [markdown]
# ## Key words Analysis

# %%
#Key words: data science, data scientist, data science bootcamp,data scientist bootcamp
#data science course, data science program
#data scientist jobs, data scientist salary

# %%
#Key words analysis :https://www.affmu.com/zh-TW/perform-text-analysis.html
#https://ahrefs.com/keywords-explorer

# %%
Tools: https://www.capterra.com/sem-compare/seo-software/?utm_source=ps-google&utm_medium=ppc&utm_campaign=:1:CAP:2:COM:3:All:4:INTL:5:BAU:6:SOF:7:Desktop:8:EX:9:SEO:11:WCI&gclid=EAIaIQobChMIieLk2vq8-gIVY__jBx1xvwkLEAAYASAAEgIK5fD_BwE

# %%
https://moz.com/mozpro/lander/keyword-research?utm_medium=cpc&utm_source=google&utm_campaign=Keyword%20Research%20Tool%20|%20NA&utm_adgroup=Keyword%20Research%20Tool%20-%20General&utm_term=keyword%20research%20tool&gclid=EAIaIQobChMI2sXjl_u8-gIVcffjBx2XiwGbEAAYAiAAEgLYA_D_BwE

# %%
https://ardentgrowth.com/blog/python-for-competitor-keyword-research/

# %%
https://www.jcchouinard.com/projects-and-resources-to-learn-python-seo/

# %% [markdown]
# ### Main webpages on data science, data scientist, data science bootcamp,data scientist bootcamp
# #Rank No.1:https://www.lighthouselabs.ca/en/data-science-bootcamp
# No.2: https://bootcamp.learn.utoronto.ca/data/
#       https://brainstation.io/course/toronto/data-science-bootcamp
#       https://www.springboard.com/courses/data-science-career-track/

# %% [markdown]
# ### weclouddata
# https://weclouddata.com/courses/online/data-science-bootcamp/
# https://weclouddata.com/courses/online/data-science-bootcamp-part-time/?gclid=EAIaIQobChMI_5WJyfa8-gIVRzizAB0UyArQEAAYASAAEgI9HvD_BwE

# %%
import advertools as adv

courses = ['Data science', 'Data Engineering', 'Business Intelligence','AI Engineering & MLOps','DevOps']
words = ['full time', 'part time']

kw_df = adv.kw_generate(courses, words)
kw_df
# Out:
#          Campaign      Ad Group                          Keyword  \
# 0    SEM_Campaign  Data Science           Data science full time
# 1    SEM_Campaign  Data Science           Data science full time
# 2    SEM_Campaign  Data Science       +Data +science +full +time
# 3    SEM_Campaign  Data Science           Data science part time
# 4    SEM_Campaign  Data Science           Data science part time
# ..            ...           ...                              ...
# 145  SEM_Campaign        Devops       part time DevOps full time
# 146  SEM_Campaign        Devops  +part +time +DevOps +full +time
# 147  SEM_Campaign        Devops       part time full time DevOps
# 148  SEM_Campaign        Devops       part time full time DevOps
# 149  SEM_Campaign        Devops  +part +time +full +time +DevOps
#
#     Criterion Type               Labels
# 0            Exact            Full Time
# 1           Phrase            Full Time
# 2            Broad            Full Time
# ...

# %%
Search Engine Results - Flights & Tickets Keywords: https://www.kaggle.com/datasets/eliasdabbas/search-engine-results-flights-tickets-keywords/code

# %% [markdown]
# ## URLs Analysis

# %%
#https://advertools.readthedocs.io/en/master/advertools.urlytics.html

# %% [markdown]
# How to Categorize URL Parameters and Queries via Python for Analyzing SEO：https://www.holisticseo.digital/python-seo/categorize-url-parameter/

# %%
#URL的语义化
#check url include years number

# %%
df_labs[['url', 'title', 'meta_desc']]
# Out:
#                                                     url  \
# 0                        https://www.lighthouselabs.ca/
# 1         https://www.lighthouselabs.ca/en/all-programs
# 2     https://enterprise.lighthouselabs.ca/?utm_sour...
# 3     https://enterprise.lighthouselabs.ca/?utm_sour...
# 4                  https://www.lighthouselabs.ca/en/faq
# ...                                                 ...
# 2083  https://21day-data-forum.lighthouselabs.ca/t/c...
# 2084  https://21day-data-forum.lighthouselabs.ca/t/c...
# 2085  https://21day-data-forum.lighthouselabs.ca/t/c...
# 2086  https://21day-data-forum.lighthouselabs.ca/t/c...
# 2087  https://21day-data-forum.lighthouselabs.ca/t/c...
#
#                                                   title  \
# 0     Canada's Leading Coding Bootcamp - Lighthouse ...
# 1                       All Programs - Lighthouse Labs
# 2                                       Lighthouse Labs
# 3                                       Lighthouse Labs
# ...

# %%
#df_url = df_labs[['url', 'title', 'meta_desc']]
df_url = df_labs[['url']]

# %%
df_url
# Out:
#                                                     url
# 0                        https://www.lighthouselabs.ca/
# 1         https://www.lighthouselabs.ca/en/all-programs
# 2     https://enterprise.lighthouselabs.ca/?utm_sour...
# 3     https://enterprise.lighthouselabs.ca/?utm_sour...
# 4                  https://www.lighthouselabs.ca/en/faq
# ...                                                 ...
# 2083  https://21day-data-forum.lighthouselabs.ca/t/c...
# 2084  https://21day-data-forum.lighthouselabs.ca/t/c...
# 2085  https://21day-data-forum.lighthouselabs.ca/t/c...
# 2086  https://21day-data-forum.lighthouselabs.ca/t/c...
# 2087  https://21day-data-forum.lighthouselabs.ca/t/c...
#
# [2088 rows x 1 columns]

# %%
#列出包含关键字的行：#list all url includes keywords:'bootcamp','data-science','data-scientist'

# %%
df_url[df_url['url'].str.contains('bootcamp')]
# Out:
#                                                     url
# 46    https://www.lighthouselabs.ca/en/blog/one-year...
# 48    https://www.lighthouselabs.ca/en/blog/one-year...
# 49    https://www.lighthouselabs.ca/en/press/press-r...
# 53    https://www.lighthouselabs.ca/en/press/lightho...
# 57    https://www.lighthouselabs.ca/en/press/coding-...
# ...                                                 ...
# 1825  https://www.lighthouselabs.ca/en/blog/one-year...
# 1829  https://www.lighthouselabs.ca/en/blog/one-year...
# 1845  https://www.lighthouselabs.ca/en/cyber-securit...
# 1850  https://www.lighthouselabs.ca/en/data-science-...
# 1854  https://www.lighthouselabs.ca/en/web-developme...
#
# [160 rows x 1 columns]

# %%
pd.set_option("display.max_colwidth",None)

# %%
df_url[df_url['url'].str.contains('bootcamp')]
# Out:
#                                                                                                                          url
# 46                                             https://www.lighthouselabs.ca/en/blog/one-year-after-bootcamp-ruxandra-fediuc
# 48             https://www.lighthouselabs.ca/en/blog/one-year-after-bootcamp-laith-azer-f4d2fb18-bed8-43a9-8665-a2022fd95c1d
# 49                 https://www.lighthouselabs.ca/en/press/press-release-coding-bootcamp-lighthouse-labs-to-launch-in-halifax
# 53                               https://www.lighthouselabs.ca/en/press/lighthouse-labs-to-bring-coding-bootcamp-to-victoria
# 57    https://www.lighthouselabs.ca/en/press/coding-bootcamp-lighthouse-labs-launches-full-time-immersive-program-in-calgary
# ...                                                                                                                      ...
# ...

# %%
df_url[df_url['url'].str.contains('data-science')]
# Out:
#                                                                                                               url
# 615                  https://www.lighthouselabs.ca/fr/blog/data-science-or-web-development-which-bootcamp-to-take
# 1049                                                      https://www.lighthouselabs.ca:443/data-science-bootcamp
# 1158                      https://www.lighthouselabs.ca:443/en/blog/data-science-careers-salaries-skills-required
# 1173           https://www.lighthouselabs.ca:443/en/blog/the-importance-of-communication-for-data-science-careers
# 1242                    https://www.lighthouselabs.ca/blog/data-science-or-web-development-which-bootcamp-to-take
# 1272                 https://www.lighthouselabs.ca/en/blog/data-science-or-web-development-which-bootcamp-to-take
# 1328                                                   https://www.lighthouselabs.ca:443/en/data-science-bootcamp
# ...

# %%
df_url[df_url['url'].str.contains('data-science-bootcamp')]
# Out:
#                                                     url
# 1049  https://www.lighthouselabs.ca:443/data-science...
# 1328  https://www.lighthouselabs.ca:443/en/data-scie...
# 1553  https://www.lighthouselabs.ca/data-science-boo...
# 1653  https://www.lighthouselabs.ca/en/blog/data-sci...
# 1689  https://www.lighthouselabs.ca/data-science-boo...
# 1850  https://www.lighthouselabs.ca/en/data-science-...

# %%
df_url[df_url['url'].str.contains('data-scientist-bootcamp')]
# Out:
# Empty DataFrame
# Columns: [url]
# Index: []

# %% [markdown]
# ## Webpage(Ranking pages), Blog, FAQ content analysis

# %%
#choose webpages including keywords: data science bootcamp

# %%
df_dsb = df_url[df_url['url'].str.contains('data-science-bootcamp')]  
df_dsb
# Out:
#                                                                                                               url
# 1049                                                      https://www.lighthouselabs.ca:443/data-science-bootcamp
# 1328                                                   https://www.lighthouselabs.ca:443/en/data-science-bootcamp
# 1553                                                          https://www.lighthouselabs.ca/data-science-bootcamp
# 1653                                 https://www.lighthouselabs.ca/en/blog/data-science-bootcamp-student-projects
# 1689  https://www.lighthouselabs.ca/data-science-bootcamp?utm_source=21ddc&utm_medium=referral&utm_campaign=about
# 1850                                                       https://www.lighthouselabs.ca/en/data-science-bootcamp

# %%
#Blog: https://www.lighthouselabs.ca/en/blog/data-science-bootcamp-student-projects

# %% [markdown]
# ### Analysis ranking webpage content:
# https://www.lighthouselabs.ca/data-science-bootcamp
# DATA SCIENCE BOOTCAMP
# Want to become a data scientist or data analyst? Apply to Canada’s top data courses today. Available online.
# includes FAQ

# %% [markdown]
# 统计关键词data science,bootcamp, data scientist, data analyst的总数
# 图片分析：https://www.holisticseo.digital/python-seo/download-image/， 分析img_src
# img_alt

# %%
import advertools as adv

#urls = ['https://netloc.com/path_1/path_2?price=10&color=blue#frag_1',
 #       'https://netloc.com/path_1/path_2?price=15&color=red#frag_2',
 #       'https://netloc.com/path_1/path_2/path_3?size=sm&color=blue#frag_1',
   #     'https://netloc.com/path_1?price=10&color=blue']
    
urls = ['https://www.lighthouselabs.ca/data-science-bootcamp']

df_url = adv.url_to_df(urls)

# %%
df_url
# Out:
#                                                    url scheme  \
# 0  https://www.lighthouselabs.ca/data-science-bootcamp  https
#
#                   netloc                    path  query  fragment  \
# 0  www.lighthouselabs.ca  /data-science-bootcamp    NaN       NaN
#
#                    dir_1               last_dir
# 0  data-science-bootcamp  data-science-bootcamp

# %%
df_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   url       1 non-null      object
#  1   scheme    1 non-null      object
#  2   netloc    1 non-null      object
#  3   path      1 non-null      object
#  4   query     0 non-null      float64
#  5   fragment  0 non-null      float64
#  6   dir_1     1 non-null      object
#  7   last_dir  1 non-null      object
# dtypes: float64(2), object(6)
# memory usage: 192.0+ bytes

# %%
# https://blog.csdn.net/weixin_54852327/article/details/115916146

# %%
https://cloud.tencent.com/developer/news/166859

# %% [markdown]
# Archive Web Pages and Websites in Bulk with Python：https://www.holisticseo.digital/python-seo/internet-archive/

# %% [markdown]
# How to Perform Text Analysis via Python and Advertools ：https://www.holisticseo.digital/python-seo/perform-text-analysis/

# %% [markdown]
# #### Text or content is a written source that conveys certain information in a certain structure, emotion and voice, and with different methodologies. Each piece of writing can be perceived as better with a specific subject in different aspects. Using different spelling techniques, sentence structures, or using different words makes the two texts on the same subject quite different from each other. It is useful to analyze content and text to see which sentence structure and form of call more useful to users and search engines. Python and Data Science are important terms of Holistic SEO. Thanks to data processing and Python, SEOs can analyze these kinds of information in a shorter time with less effort.

# %%
Absolute and Weighted Frequency

# %%
import advertools as adv
import pandas as pd
pd.set_option('display.max_rows', 85)

text = "Since 2013, we’ve been offering outcomes-driven education to over 4,000 career-minded students and successfully delivered immersive remote education to students around the country.\
As of March 2020, our programs are online to ensure the safety of our community and make our students more ready for the work from home culture that is growing in demand."

adv.word_frequency(text).head(20)
# Out:
#           word  abs_freq
# 0     students         3
# 1    education         2
# 2         2013         1
# 3         2020         1
# 4      growing         1
# 5      culture         1
# 6         home         1
# 7         work         1
# 8        ready         1
# 9    community         1
# 10      safety         1
# 11      ensure         1
# 12      online         1
# 13    programs         1
# 14       march         1
# 15       we’ve         1
# 16  country.as         1
# 17      remote         1
# 18   immersive         1
# 19   delivered         1

# %% [markdown]
# text = Since 2013, we’ve been offering outcomes-driven education to over 4,000 career-minded students and successfully delivered immersive remote education to students around the country.\
# As of March 2020, \
# our programs are online to ensure the safety of our community and make our students more ready for the work from home culture that is growing in demand.\
# Same great education & career services, also available online."

# %%
adv.stopwords.keys()
# Out:
# dict_keys(['arabic', 'azerbaijani', 'bengali', 'catalan', 'chinese', 'croatian', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hindi', 'hungarian', 'indonesian', 'irish', 'italian', 'japanese', 'kazakh', 'nepali', 'norwegian', 'persian', 'polish', 'portuguese', 'romanian', 'russian', 'sinhala', 'spanish', 'swedish', 'tagalog', 'tamil', 'tatar', 'telugu', 'thai', 'turkish', 'ukrainian', 'urdu', 'vietnamese'])

# %%
adv.word_frequency(text, phrase_len=3).head(20)
# Out:
#                    word  abs_freq
# 0      since 2013 we’ve         1
# 1       2013 we’ve been         1
# 2         are online to         1
# 3      online to ensure         1
# 4         to ensure the         1
# 5     ensure the safety         1
# 6         the safety of         1
# 7         safety of our         1
# 8      of our community         1
# 9     our community and         1
# 10   community and make         1
# 11         and make our         1
# 12    make our students         1
# 13    our students more         1
# 14  students more ready         1
# 15       more ready for         1
# 16        ready for the         1
# 17         for the work         1
# 18        the work from         1
# 19       work from home         1

# %%
adv.word_frequency(text, phrase_len=1, rm_words=['the','and', 'his', 'to', 'in', 'a', 'he', 'at', 'of', 'from', 'was', 'as']).head(20)
# Out:
#          word  abs_freq
# 0    students         3
# 1         our         3
# 2   education         2
# 3     growing         1
# 4        more         1
# 5         are         1
# 6      online         1
# 7      ensure         1
# 8      safety         1
# 9   community         1
# 10       make         1
# 11      ready         1
# 12         is         1
# 13   programs         1
# 14        for         1
# 15       work         1
# 16       home         1
# 17    culture         1
# 18       that         1
# 19      since         1

# %%
#把主网页的各段落爬到CSV中

# %%
queries = pd.read_csv(‘Queries-ex.csv’, index_col=None)
adv.word_frequency(queries[‘Query’]).head(30)

# %%
adv.word_frequency(queries[‘Query’], phrase_len=3).head(30)

# %%
adv.word_frequency(queries[‘Query’], queries[‘Impressions’], phrase_len=2).head(30)

# %%
weighted_fr = adv.word_frequency(queries[‘Query’], queries[‘Impressions’], phrase_len=2).head(30)
weighted_fr.sort_values(by=’wtd_freq’, ascending=False)

# %%
weighted_fr = adv.word_frequency(queries[‘Query’], queries[‘Clicks’], extra_info=True, phrase_len=2).head(30)
weighted_fr.sort_values(by=’wtd_freq’, ascending=False)

# %% [markdown]
# #check url levels: URL结构规范化中最重要的一点就是层级关系结构，也就是前面说的子目录形式，
# 通常我们的子目录最大层级只会做到3级，也就是经过两个目录最终第三层能够到达实际的文章页，层级太深不利于收录。

# %%
#

# %% [markdown]
# ### Internal Link Analysis with Python: https://www.briggsby.com/internal-link-analysis-with-python

# %% [markdown]
# ## Search engine results pages (SERPs) research

# %%
https://www.kaggle.com/code/candongguo/search-engine-results-pages-serps-research/edit

# %%
https://www.holisticseo.digital/python-seo/data-science/;https://www.holisticseo.digital/python-seo/data-science/

# %%
To connect the Google Custom Search API and retrieve Google Search Results with Python, you need two things.

Google Developer Console Account
Custom Search API Key
Custom Search Engine ID.

# %%
# !pip install "advertools==0.7.4"

# %%
#import pandas as pd
#(pd.read_csv('../input/pymarketing.csv').head())

# %% [markdown]
# ### Approach
# We will connect to Google's custom search engine API: This is mainly used to create a search engine on your website, and allows you to customize it. We will use it to get results for research purposes:
#
# Create a custom search engine. At first you might be asked to enter a site to search. Enter any domain, then go to the control panel and remove it. Make sure you enable "Search the entire web" and image search. You will also need to get your search engine ID, which you can find on the control panel page.
# Enable the custom search API. You wil need to create a project for this first.
# create credentials for this project so you can get your key.
# enable billing for your project If you want to run more than 100 queries per day. The first 100 queries are free, then for each 1,000 queries you pay $5.
# Once this is set up (once you have your custom search engine ID, and your key), we will be ready to construct our queries and get the data.
#
# We will be using the serp_goog function from the advertools package. To install it:
# pip install advertools
#
# Start first be defining two variable as we will be using them in every request. I'm using the conventions used by Google's CSE:

# %% [markdown]
# Search engine ID:
# 419f2d285fb7e4111
#
# API Access Key:
# AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM

# %%
#ID: cx, API KEY:key
cx = '419f2d285fb7e4111'
key = 'AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM'

import advertools as adv
import pandas as pd
pd.options.display.max_columns = None

import plotly
import plotly.graph_objs as go

for p in [adv, pd, plotly]:
    print(p.__name__, p.__version__)
# Out:
# advertools 0.13.1
# pandas 1.4.2
# plotly 5.6.0

# %%
data_science_bootcamp = adv.serp_goog(q='data science bootcamp', cx=cx, key=key)
# Out:
# 2022-10-02 18:06:23,719 | INFO | serp.py:728 | serp_goog | Requesting: q=data science bootcamp, cx=419f2d285fb7e4111, key=AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM

# %%
#https://advertools.readthedocs.io/en/master/advertools.serp.html

# %% [markdown]
# import advertools as adv
# api_key, cse_id = "YOUR API KEY", "YOUR CSE ID"
# adv.serp_goog(key=api_key, cx=cse_id, q="Example Query", gl=["example country code"])

# %%
# !pip install schedule

# %%
import schedule 
import advertools as adv
api_key, cse_id = "AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM", "419f2d285fb7e4111"

#df_ds = adv.serp_goog(key=api_key, cx=cse_id, q="data science bootcamp", gl=['ca','us','au'])

df_ds = adv.serp_goog(key=api_key, cx=cse_id, q="data science bootcamp", gl=['ca','us'])
# Out:
# 2022-10-02 19:32:19,542 | INFO | serp.py:728 | serp_goog | Requesting: q=data science bootcamp, cx=419f2d285fb7e4111, key=AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM, gl=ca
# 2022-10-02 19:32:19,963 | INFO | serp.py:728 | serp_goog | Requesting: q=data science bootcamp, cx=419f2d285fb7e4111, key=AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM, gl=us

# %%
df_ds.head()
# Out:
#    gl            searchTerms  rank  \
# 0  ca  data science bootcamp     1
# 1  ca  data science bootcamp     2
# 2  ca  data science bootcamp     3
# 3  ca  data science bootcamp     4
# 4  ca  data science bootcamp     5
#
#                                                        title  \
# 0               Data Science Bootcamp Online | BrainStation®
# 1  Data Science Bootcamp: Online + 100% Money Back Guarantee
# 2                    Data Science Bootcamp - Lighthouse Labs
# 3       UofT SCS Data Analytics Boot Camp | Toronto | Online
# 4                Data Science Bootcamp - Concordia Bootcamps
#
#                                                                                                                                                                   snippet  \
# 0                  BrainStation's Data Science bootcamps are intensive learning experiences designed to transform your skillset and help you launch a new career in data.
# ...

# %%
df_ds.shape
# Out:
# (20, 93)

# %%
df_ds.columns
# Out:
# Index(['gl', 'searchTerms', 'rank', 'title', 'snippet', 'displayLink', 'link',
#        'queryTime', 'totalResults', 'cacheId', 'count', 'cseName', 'cx',
#        'formattedSearchTime', 'formattedTotalResults', 'formattedUrl',
#        'htmlFormattedUrl', 'htmlSnippet', 'htmlTitle', 'inputEncoding', 'kind',
#        'outputEncoding', 'pagemap', 'safe', 'searchTime', 'startIndex',
#        'cse_thumbnail', 'EducationEvent', 'metatags', 'cse_image', 'Course',
#        'organization', 'msapplication-tilecolor', 'msapplication-config',
#        'og:image', 'og:type', 'twitter:title', 'twitter:card', 'og:site_name',
#        'twitter:url', 'og:title', 'msapplication-tileimage', 'og:description',
#        'twitter:image', 'twitter:site', 'viewport', 'twitter:description',
#        'og:url', 'image', 'fb:app_id', 'csrf-param',
#        'facebook-domain-verification', 'twitter:image:src', 'csrf-token',
#        'msvalidate.01', 'admission-type', 'twitter:label1', 'twitter:data1',
# ...

# %%
import datetime

def SERPdsbootcamp():
    """
    Calls the function with the determined frequency, for the determined queries.
    Creates a CSV Output with the name of the actual date which the function called.
    """
    date = datetime.now()
    date = date.strftime("%d%m%Y%H_%M_%S")
    
    df = adv.serp_goog(
        q=['data science', "bootcamp"], key=api_key, cx=cse_id, gl=["us","ca"], start=[1,11,21,31,41,51,61,71,81,91])
    
    df.to_csv(f'serp_recording_{date}_' + '_' + 'scheduled_serp.csv')


schedule.every(10).minutes.do(SERPdsbootcamp)
# Out:
# Every 10 minutes do SERPdsbootcamp() (last run: [never], next run: 2022-10-02 19:47:09)

# %%
from datetime import datetime
import time

n=0
while n<99:
    SERPdsbootcamp()
    time.sleep(1)
    n += 1
# Out:
# 2022-10-02 19:39:57,261 | INFO | serp.py:728 | serp_goog | Requesting: q=data science, cx=419f2d285fb7e4111, key=AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM, gl=us, start=1
# 2022-10-02 19:39:57,665 | INFO | serp.py:728 | serp_goog | Requesting: q=data science, cx=419f2d285fb7e4111, key=AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM, gl=us, start=11
# 2022-10-02 19:39:58,031 | INFO | serp.py:728 | serp_goog | Requesting: q=data science, cx=419f2d285fb7e4111, key=AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM, gl=us, start=21
# 2022-10-02 19:39:58,538 | INFO | serp.py:728 | serp_goog | Requesting: q=data science, cx=419f2d285fb7e4111, key=AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM, gl=us, start=31
# 2022-10-02 19:39:58,981 | INFO | serp.py:728 | serp_goog | Requesting: q=data science, cx=419f2d285fb7e4111, key=AIzaSyC4osijdjTd9a77mGGSRcmA7EiUNkUtvrM, gl=us, start=41
# ...

# %%
#data_science_bootcamp = pd.read_csv('/data_science_bootcamp.csv', parse_dates=['queryTime'])
#print(data_science_bootcamp.shape)
#data_science_bootcamp.head(3)

# %%
df_1 = pd.read_csv("first_csv_output.csv", index_col='queryTime')
df_2 = pd.read_csv("second_csv_output.csv", index_col='queryTime')
df_3 = pd.read_csv("third_csv_output.csv", index_col='queryTime')
df_4 = pd.read_csv("fourth_csv_output.csv", index_col='queryTime')

united_serp_df = df_1.append([df_2,df_3,df_4])

serp_csv.drop(columns="Unnamed: 0", inplace=True)
serp_csv.set_index("queryTime", inplace=True)

# %% [markdown]
# ### Robots.txt analysis

# %%
#https://www.holisticseo.digital/python-seo/verify-test-robots-txt-file/

# %%
from advertools import robotstxt_test
robotstxt_test('https://www.lighthouselabs.com/robots.txt', user_agents=['*'], urls=['/ads/'])
# Out:
#                                robotstxt_url user_agent url_path  can_fetch
# 0  https://www.lighthouselabs.com/robots.txt          *    /ads/       True

# %% [markdown]
# The first column which is “robotstxt_url” shows the robots.txt URL, we are testing according to.
# The “user-agent” column shows the user-agents we are testing.
# “url_path” shows the URL snippet we are testing for.
# “can_fetch” takes only “true” or “false” values.
# In this example, it is “True/False” which means that it is allowed/disallowed.

# %%
robotstxt_test('https://www.lighthouselabs.com/robots.txt', user_agents=['Googlebot', 'Twitterbot', 'AhrefsBot', 'Googlebot-News', 'SemrushBot-BA'], urls=['/', 'amp', 'search'])
# Out:
#                                 robotstxt_url      user_agent url_path  \
# 0   https://www.lighthouselabs.com/robots.txt       AhrefsBot        /
# 1   https://www.lighthouselabs.com/robots.txt       AhrefsBot      amp
# 2   https://www.lighthouselabs.com/robots.txt       AhrefsBot   search
# 3   https://www.lighthouselabs.com/robots.txt       Googlebot        /
# 4   https://www.lighthouselabs.com/robots.txt       Googlebot      amp
# 5   https://www.lighthouselabs.com/robots.txt       Googlebot   search
# 6   https://www.lighthouselabs.com/robots.txt  Googlebot-News        /
# 7   https://www.lighthouselabs.com/robots.txt  Googlebot-News      amp
# 8   https://www.lighthouselabs.com/robots.txt  Googlebot-News   search
# 9   https://www.lighthouselabs.com/robots.txt   SemrushBot-BA        /
# 10  https://www.lighthouselabs.com/robots.txt   SemrushBot-BA      amp
# 11  https://www.lighthouselabs.com/robots.txt   SemrushBot-BA   search
# ...

# %%
we_robots = 'https://www.weclouddata.com/robots.txt'
robotstxt_test(we_robots, user_agents=['Googlebot', 'Googlebot-News', 'Twitterbot', 'AhrefsBot', 'SemrushBot-BA'], urls=['/', '/amphtml/', 'ads'])
# Out:
#                              robotstxt_url      user_agent   url_path  \
# 0   https://www.weclouddata.com/robots.txt       AhrefsBot          /
# 1   https://www.weclouddata.com/robots.txt       AhrefsBot  /amphtml/
# 2   https://www.weclouddata.com/robots.txt       AhrefsBot        ads
# 3   https://www.weclouddata.com/robots.txt       Googlebot          /
# 4   https://www.weclouddata.com/robots.txt       Googlebot  /amphtml/
# 5   https://www.weclouddata.com/robots.txt       Googlebot        ads
# 6   https://www.weclouddata.com/robots.txt  Googlebot-News          /
# 7   https://www.weclouddata.com/robots.txt  Googlebot-News  /amphtml/
# 8   https://www.weclouddata.com/robots.txt  Googlebot-News        ads
# 9   https://www.weclouddata.com/robots.txt   SemrushBot-BA          /
# 10  https://www.weclouddata.com/robots.txt   SemrushBot-BA  /amphtml/
# 11  https://www.weclouddata.com/robots.txt   SemrushBot-BA        ads
# ...

# %%
# If you want to test more URL Paths, you can use the “robotstxt_to_df()” function so that you can see URL Paths to test them as bulk.

# %% [markdown]
# ## Log File Analysis
# https://advertools.readthedocs.io/en/master/advertools.logs.html#how-to-run-the-logs-to-df-function

# %%
# !head data/weclouddata.log
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#conda install posix

# %%
# !head data/weclouddata.log
# Out:
# head: cannot open 'data/weclouddata.log' for reading: No such file or directory

# %%
 # !head C:/WeCloudData/Clientproject/Notebook/weclouddata.log
# Out:
# 2022-09-22 10:38:35 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-09-22 10:38:35 [scrapy.utils.log] INFO: Versions: lxml 4.8.0.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 21.0.0 (OpenSSL 1.1.1o  3 May 2022), cryptography 3.4.8, Platform Windows-10-10.0.22000-SP0
# 2022-09-22 10:38:35 [numexpr.utils] INFO: NumExpr defaulting to 8 threads.
# 2022-09-22 10:38:36 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_FILE': 'weclouddata.log',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_LOADER_WARN_ONLY': True,
#  'USER_AGENT': 'advertools/0.13.1'}
# 2022-09-22 10:38:36 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-09-22 10:38:36 [scrapy.extensions.telnet] INFO: Telnet Password: c3fd1e86ee73a8fd

# %%
# !pip install pyyaml ua-parser user-agents

# %%
import advertools as adv
import pandas as pd
from ua_parser import user_agent_parser
pd.options.display.max_columns = None

adv.logs_to_df(log_file='C:/WeCloudData/Clientproject/Notebook/weclouddata.log',
               output_file='C:/WeCloudData/Clientproject/Notebook/adv_logs.parquet',
               errors_file='C:/WeCloudData/Clientproject/Notebook/adv_errors.txt',
               log_format='combined')
# Out:
# Parsed           1,086 lines.

# %%
logs_df = pd.read_parquet('C:/WeCloudData/Clientproject/Notebook/adv_logs.parquet')
logs_df['datetime'] = pd.to_datetime(logs_df['datetime'],
                                     format='%d/%b/%Y:%H:%M:%S %z')

logs_df
# Out:
# Empty DataFrame
# Columns: [client, userid, datetime, method, request, status, size, referer, user_agent]
# Index: []

# %% [markdown]
# # XML Sitemaps
#
# The function `sitemap_to_df` crawls (multiple) sitemaps, and converts them to a DataFrame. It can take a regular sitemap, or a sitemap index.
#
#
# `import advertools as adv`
# `weclouddata_sitemap = adv.sitemap_to_df('https://www.weclouddata.com/sitemap.xml')`

# %%
# https://www.holisticseo.digital/python-seo/content-analysis-with-sitemaps/

# %%
# https://advertools.readthedocs.io/en/master/advertools.sitemaps.html#sitemaps

# %% [markdown]
# ### A sitemap is the name of an XML File that collects URLs that must be indexed by the Search Engine on a website. Sitemap Files can contain data on URL Categories, URL publishes date, URL content, content-language, content author, subject, etc.

# %%
import advertools as adv

labs_sitemap = adv.sitemap_to_df('https://www.lighthouselabs.ca/sitemap.xml')
# Out:
# 2022-09-30 14:19:49,232 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lighthouselabs.ca/sitemap.xml

# %%
sitemaps_df = labs_sitemap

# %%
#sitemaps_df = pd.read_csv('C:/WeCloudData/Clientproject/Kaggle/SEO Crawl Analysis Template/data/weclouddata_sitemaps.csv')

sitemaps_df.head()
# Out:
#                                                  loc  \
# 0                      https://www.lighthouselabs.ca
# 1  https://www.lighthouselabs.ca/en/web-developme...
# 2  https://www.lighthouselabs.ca/en/data-science-...
# 3  https://www.lighthouselabs.ca/en/intro-web-dev...
# 4  https://www.lighthouselabs.ca/en/intro-front-e...
#
#                     lastmod changefreq  priority  \
# 0 2022-09-29 20:24:16+00:00     always       1.0
# 1 2022-09-29 20:24:16+00:00     weekly       0.9
# 2 2022-09-29 20:24:16+00:00     weekly       0.9
# 3 2022-09-29 20:24:16+00:00     weekly       0.9
# 4 2022-09-29 20:24:16+00:00     weekly       0.9
#
#                                      sitemap              etag  \
# 0  https://www.lighthouselabs.ca/sitemap.xml  "6335fef0-1a18e"
# 1  https://www.lighthouselabs.ca/sitemap.xml  "6335fef0-1a18e"
# 2  https://www.lighthouselabs.ca/sitemap.xml  "6335fef0-1a18e"
# 3  https://www.lighthouselabs.ca/sitemap.xml  "6335fef0-1a18e"
# ...

# %%
sitemaps_df.shape
# Out:
# (470, 9)

# %% [markdown]
# ###  We have 6 different columns in total.
#
# “loc” column is for the “URLs” in the sitemap that we are crawled and turned into the data frame.
#
# “lastmod” column is for the “content’s publishing date” or the “content’s updated date”.
#
# “changefreq” is not important for Google Search Engine but still it might reflect the understanding of the web site owner.
#
# “priority” is also not important for Google Search Engine, but still it might reflect some important points.
#
# “Sitemap” column is for “sitemap index” files. In some web sites, we may encounter more than one web site which is categorized based on the post type or the post category. This categorization may help us to analyze a web entity easier and with less code. In this guideline, for now, we won’t perform this section.
#
# “download_date” column is for showing the date that is relevant to our process.

# %%
sitemaps_df.to_csv('sitemaps_urls.csv', index=False)
df = pd.read_csv('sitemaps_urls.csv', index_col='lastmod', mangle_dupe_cols=True)

# %%
df
# Out:
#                                                                          loc  \
# lastmod
# 2022-09-29 20:24:16+00:00                      https://www.lighthouselabs.ca
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/en/web-developme...
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/en/data-science-...
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/en/intro-web-dev...
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/en/intro-front-e...
# ...                                                                      ...
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/fr/partenariats-...
# 2022-09-29 20:24:16+00:00               https://www.lighthouselabs.ca/fr/faq
# 2022-09-29 20:24:16+00:00           https://www.lighthouselabs.ca/fr/demande
# 2022-09-29 20:24:16+00:00        https://www.lighthouselabs.ca/fr/communaute
# 2022-09-29 20:24:16+00:00           https://www.lighthouselabs.ca/fr/projets
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 470 entries, 2022-09-29 20:24:16+00:00 to 2022-09-29 20:24:16+00:00
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   loc                    470 non-null    object
#  1   changefreq             470 non-null    object
#  2   priority               470 non-null    float64
#  3   sitemap                470 non-null    object
#  4   etag                   470 non-null    object
#  5   sitemap_last_modified  470 non-null    object
#  6   sitemap_size_mb        470 non-null    float64
#  7   download_date          470 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 33.0+ KB

# %%
#Before proceeding more and deep diving, let’s import “plotly graph objects” module so that we can drive some insights.

# %%
priority = df.groupby('priority').count()
priority
# Out:
#           loc  changefreq  sitemap  etag  sitemap_last_modified  \
# priority
# 0.3         2           2        2     2                      2
# 0.5        24          24       24    24                     24
# 0.6         8           8        8     8                      8
# 0.7       410         410      410   410                    410
# 0.8         6           6        6     6                      6
# 0.9        19          19       19    19                     19
# 1.0         1           1        1     1                      1
#
#           sitemap_size_mb  download_date
# priority
# 0.3                     2              2
# 0.5                    24             24
# 0.6                     8              8
# 0.7                   410            410
# 0.8                     6              6
# 0.9                    19             19
# 1.0                     1              1

# %%
from plotly.subplots import make_subplots

# %%
#from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=2)
fig.add_trace(
    go.Bar(x=priority.index, y=priority['loc'], name='Loc'),
    row=1,col=1)
fig.add_trace(
    go.Bar(x=priority.index, y=priority['changefreq'], name='Changefreq'),
    row=1, col=2)
fig.layout.title = 'Priority and Changefreq Distrubition for lighthouselabs.da'
fig.layout.yaxis.title = 'Number of URLs'
fig.layout.paper_bgcolor = '#E5ECF6'
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 3>()
#       1 from plotly.subplots import make_subplots
#       2 fig = make_subplots(rows=1, cols=2)
#       3 fig.add_trace(
# ----> 4     go.Bar(x=priority.index, y=priority['loc'], name='Loc'),
#       5     row=1,col=1)
#       6 fig.add_trace(
#       7     go.Bar(x=priority.index, y=priority['changefreq'], name='Changefreq'),
#       8     row=1, col=2)
#       9 fig.layout.title = 'Priority and Changefreq Distrubition for lighthouselabs.da'
#
# NameError: name 'go' is not defined

# %% [markdown]
# ### How to Analyze a Web Site’s Content Publishing and Updating Trend via Sitemaps and Python

# %% [markdown]
# #### To perform a trend analysis for content publishing frequency and timing, we need to use our “lastmod” column which is index at the same time. Before proceeding more, we should check whether our sitemap has a “NaN” value for the “lastmod” column or not.

# %%
#df[df.index.isna()]
# Out:
# Empty DataFrame
# Columns: [loc, changefreq, priority, sitemap, etag, sitemap_last_modified, sitemap_size_mb, download_date]
# Index: []

# %%
#df.index = pd.to_datetime(df.index)
#ppyear= df.resample('A')['loc'].count()
#ppyear.to_frame()
# Out:
#                            loc
# lastmod
# 2022-12-31 00:00:00+00:00  470

# %%
df.head()
# Out:
#                                                                          loc  \
# lastmod
# 2022-09-29 20:24:16+00:00                      https://www.lighthouselabs.ca
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/en/web-developme...
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/en/data-science-...
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/en/intro-web-dev...
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/en/intro-front-e...
#
#                           changefreq  priority  \
# lastmod
# 2022-09-29 20:24:16+00:00     always       1.0
# 2022-09-29 20:24:16+00:00     weekly       0.9
# 2022-09-29 20:24:16+00:00     weekly       0.9
# 2022-09-29 20:24:16+00:00     weekly       0.9
# 2022-09-29 20:24:16+00:00     weekly       0.9
#
#                                                              sitemap  \
# lastmod
# 2022-09-29 20:24:16+00:00  https://www.lighthouselabs.ca/sitemap.xml
# ...

# %%
df.columns
# Out:
# Index(['loc', 'changefreq', 'priority', 'sitemap', 'etag',
#        'sitemap_last_modified', 'sitemap_size_mb', 'download_date'],
#       dtype='object')

# %%
df['sitemap_last_modified'] = pd.to_datetime(df['sitemap_last_modified'])

# %%
df.set_index(df['sitemap_last_modified'], inplace=True)

# %%
ppmonth2 = df.resample('M')['loc'].count()
ppmonth2.to_frame()
# Out:
#                            loc
# sitemap_last_modified
# 2022-09-30 00:00:00+00:00  470

# %%
ppmonth2
# Out:
# sitemap_last_modified
# 2022-09-30 00:00:00+00:00    470
# Freq: M, Name: loc, dtype: int64

# %%
fig = go.Figure()
fig.add_scatter(x=ppmonth2.index, y=ppmonth2.values, name='Lighthouselabs')
fig.layout.paper_bgcolor='#E5ECF6'
fig.layout.yaxis.title='Number of Articles per Month'
fig.layout.title='Koalay Article Publishing and Updating Trends'
fig.show()

# %%
import advertools as adv

labs_sitemap = adv.sitemap_to_df('https://www.lighthouselabs.ca/sitemap.xml')
# Out:
# 2022-09-30 14:50:50,406 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lighthouselabs.ca/sitemap.xml

# %%
labs_sitemap['sitemap'].unique()
# Out:
# array(['https://www.lighthouselabs.ca/sitemap.xml'], dtype=object)

# %%
labs_sitemap
# Out:
#                                                    loc  \
# 0                        https://www.lighthouselabs.ca
# 1    https://www.lighthouselabs.ca/en/web-developme...
# 2    https://www.lighthouselabs.ca/en/data-science-...
# 3    https://www.lighthouselabs.ca/en/intro-web-dev...
# 4    https://www.lighthouselabs.ca/en/intro-front-e...
# ..                                                 ...
# 465  https://www.lighthouselabs.ca/fr/partenariats-...
# 466               https://www.lighthouselabs.ca/fr/faq
# 467           https://www.lighthouselabs.ca/fr/demande
# 468        https://www.lighthouselabs.ca/fr/communaute
# 469           https://www.lighthouselabs.ca/fr/projets
#
#                       lastmod changefreq  priority  \
# 0   2022-09-29 20:24:16+00:00     always       1.0
# 1   2022-09-29 20:24:16+00:00     weekly       0.9
# 2   2022-09-29 20:24:16+00:00     weekly       0.9
# 3   2022-09-29 20:24:16+00:00     weekly       0.9
# ...

# %%
labs_sitemap
# Out:
#                                                    loc  \
# 0                        https://www.lighthouselabs.ca
# 1    https://www.lighthouselabs.ca/en/web-developme...
# 2    https://www.lighthouselabs.ca/en/data-science-...
# 3    https://www.lighthouselabs.ca/en/intro-web-dev...
# 4    https://www.lighthouselabs.ca/en/intro-front-e...
# ..                                                 ...
# 465  https://www.lighthouselabs.ca/fr/partenariats-...
# 466               https://www.lighthouselabs.ca/fr/faq
# 467           https://www.lighthouselabs.ca/fr/demande
# 468        https://www.lighthouselabs.ca/fr/communaute
# 469           https://www.lighthouselabs.ca/fr/projets
#
#                       lastmod changefreq  priority  \
# 0   2022-09-29 20:24:16+00:00     always       1.0
# 1   2022-09-29 20:24:16+00:00     weekly       0.9
# 2   2022-09-29 20:24:16+00:00     weekly       0.9
# 3   2022-09-29 20:24:16+00:00     weekly       0.9
# ...

# %%
#labs_sitemap['sitemap_name'] = labs_sitemap['sitemap'].str.split('/').str[4]

# %%
labs_sitemap['sitemap'].replace('https://www.lighthouselabs.ca/sitemap.xml', 'lighthouselabs', inplace=True)
labs_sitemap
# Out:
#                                                    loc  \
# 0                        https://www.lighthouselabs.ca
# 1    https://www.lighthouselabs.ca/en/web-developme...
# 2    https://www.lighthouselabs.ca/en/data-science-...
# 3    https://www.lighthouselabs.ca/en/intro-web-dev...
# 4    https://www.lighthouselabs.ca/en/intro-front-e...
# ..                                                 ...
# 465  https://www.lighthouselabs.ca/fr/partenariats-...
# 466               https://www.lighthouselabs.ca/fr/faq
# 467           https://www.lighthouselabs.ca/fr/demande
# 468        https://www.lighthouselabs.ca/fr/communaute
# 469           https://www.lighthouselabs.ca/fr/projets
#
#                       lastmod changefreq  priority         sitemap  \
# 0   2022-09-29 20:24:16+00:00     always       1.0  lighthouselabs
# 1   2022-09-29 20:24:16+00:00     weekly       0.9  lighthouselabs
# 2   2022-09-29 20:24:16+00:00     weekly       0.9  lighthouselabs
# ...

# %% [markdown]
# ### How to Categorize URLs via Sitemaps and Python for Analyzing Content Structure

# %%
sitemaps_df.columns
# Out:
# Index(['loc', 'lastmod', 'image', 'image_loc', 'image_caption', 'image_title',
#        'sitemap', 'sitemap_size_mb', 'download_date'],
#       dtype='object')

# %%
sitemaps_df['sitemap'].value_counts().to_frame().style.background_gradient(cmap='cividis').format('{:,}')
# Out:
# <style type="text/css">
# #T_f8ecd_row0_col0 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_f8ecd_row1_col0 {
#   background-color: #c1b26a;
#   color: #000000;
# }
# #T_f8ecd_row2_col0, #T_f8ecd_row3_col0 {
#   background-color: #b4a76f;
#   color: #f1f1f1;
# }
# #T_f8ecd_row4_col0 {
#   background-color: #928d78;
#   color: #f1f1f1;
# }
# #T_f8ecd_row5_col0 {
#   background-color: #817f78;
#   color: #f1f1f1;
# }
# #T_f8ecd_row6_col0 {
#   background-color: #646770;
#   color: #f1f1f1;
# }
# #T_f8ecd_row7_col0 {
#   background-color: #434e6c;
#   color: #f1f1f1;
# }
# #T_f8ecd_row8_col0 {
#   background-color: #32436d;
#   color: #f1f1f1;
# }
# #T_f8ecd_row9_col0 {
#   background-color: #013271;
#   color: #f1f1f1;
# }
# #T_f8ecd_row10_col0 {
#   background-color: #003070;
#   color: #f1f1f1;
# }
# #T_f8ecd_row11_col0 {
#   background-color: #002e6c;
#   color: #f1f1f1;
# }
# #T_f8ecd_row12_col0 {
#   background-color: #002d68;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ### 爬网页

# %%
# !pip install BeautifulSoup4
